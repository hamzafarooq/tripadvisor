# %%
import requests
from bs4 import BeautifulSoup
import csv
import webbrowser
import pandas as pd
import io
from review_v2 import scrape, write_in_csv
#!/usr/bin/env python
from datetime import datetime
from time import time
from lxml import html,etree
from reviews_final import scrape, write_in_csv
import pandas as pd
import requests,re
import os,sys
import unicodecsv as csv
import argparse

# %%
# %run trip_advisor_final.py "2022/01/01" "2022/01/05" "recommended" "Paris"
# Out:
# Scraper Inititated for Locality:Paris
# Finding search result page URL
# URL found http://www.tripadvisor.com/Hotels-g187147-Paris_Ile_de_France-Hotels.html
# http://www.tripadvisor.com/Hotels-g187147-Paris_Ile_de_France-Hotels.html
# ...
# Parsing results
# http://www.tripadvisor.com/Hotels-g187147-oa30-Paris_Ile_de_France-Hotels.html
# ...
# Parsing results
# http://www.tripadvisor.com/Hotels-g187147-oa60-Paris_Ile_de_France-Hotels.html
# ...
# Parsing results
# Writing to output file tripadvisor_data.csv
# [parse] url: https://www.tripadvisor.com/Hotel_Review-g187147-d197520-Reviews-Hotel_Elysees_Flaubert-Paris_Ile_de_France.html
# [parse] url_template: https://www.tripadvisor.com/Hotel_Review-g187147-d197520-Reviews-Hotel_Elysees_Flaubert-Paris_Ile_de_France-or{}.html
# [parse_reviews] url: https://www.tripadvisor.com/Hotel_Review-g187147-d197520-Reviews-Hotel_Elysees_Flaubert-Paris_Ile_de_France-or0.html
# [get_reviews_ids] data-reviewid: ['738625597', '724556832', '707870709']
# ...

# %%
import pandas as pd

# %%
df_reviews = pd.read_csv('hotelReviewsInPrague__en2022010120220105.csv')

# %%
len(df_reviews['hotelName'].drop_duplicates())
# Out:
# 92

# %%
df_reviews['hotelName'].value_counts()
# Out:
# 0     Numa l Libusa Apartments\n31    Numa l Libusa Apartments\n69    Numa l Libusa Apartments\nName: hotel_name, dtype: object    15
# 37    Charles Bridge Hostel & Apartments\n63    Charles Bridge Hostel & Apartments\nName: hotel_name, dtype: object                10
# 59    Hotel U Prince\nName: hotel_name, dtype: object                                                                               5
# 70    Ibis Praha Wenceslas Square\nName: hotel_name, dtype: object                                                                  5
# 68    Hotel Aida\nName: hotel_name, dtype: object                                                                                   5
#                                                                                                                                    ..
# 28    H7 Palace\nName: hotel_name, dtype: object                                                                                    5
# ...

# %%
df_reviews.head()
# Out:
#    Unnamed: 0                                        review_body  \
# 0           0  Location: maybe the best about the hotel is it...
# 1           1  The hotel is located in a more residential are...
# 2           2  Very nice hotel, spotlessly clean and comfy be...
# 3           3  The hotel is pretty well situated just 10 minu...
# 4           4  We stayed there 3 nights, everything was great...
#
#       review_date                                          hotelName  \
# 0   December 2019  0     Hotel Elysees Flaubert\n38    Hotel Elys...
# 1    October 2019  0     Hotel Elysees Flaubert\n38    Hotel Elys...
# 2   November 2019  0     Hotel Elysees Flaubert\n38    Hotel Elys...
# 3    October 2019  0     Hotel Elysees Flaubert\n38    Hotel Elys...
# 4  September 2019  0     Hotel Elysees Flaubert\n38    Hotel Elys...
#
#                                             hotelUrl
# 0  https://www.tripadvisor.com/Hotel_Review-g1871...
# ...
